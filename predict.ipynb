# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[0], [1], [2], [3]])
y = np.array([2, 3, 4, 5])

model = LinearRegression()
clf = model.fit(X, y)
print('Coefficient: ', clf.coef_)
print('Intercept: ', clf.intercept_)
# Out:
# Coefficient:  [1.]
# Intercept:  2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = np.array([[0], [1], [2], [3], [4], [5], [6], [7]])
y = np.array([2, 3, 9, 13, 27, 84, 105, 169])

plt.scatter(X, y)

model = LinearRegression()
clf = model.fit(X, y)
predictions = np.dot(X, clf.coef_)

for index in range(len(predictions)):
    predictions[index] = predictions[index] +clf.intercept_

plt.plot(X, predictions)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
data = pd.read_csv('auto-mpg.csv')

X = data[['weight']].values
y = data['mpg']

plt.scatter(X, y)

model = LinearRegression()
clf = model.fit(X, y)
print('Coefficient: ', clf.coef_)


predictions = model.predict(X)
for index in range(len(predictions)):
    print ('Actual: ', y[index], '    ', 'Predicted: ', format(predictions[index], ".1f"),'    ', 'Weight: ', X[index, 0])
#plt.plot(X, predictions)
# Out:
# Coefficient:  [-0.00767661]
# Actual:  18.0      Predicted:  19.4      Weight:  3504
# Actual:  15.0      Predicted:  18.0      Weight:  3693
# Actual:  18.0      Predicted:  19.9      Weight:  3436
# Actual:  16.0      Predicted:  20.0      Weight:  3433
# Actual:  17.0      Predicted:  19.8      Weight:  3449
# Actual:  15.0      Predicted:  13.0      Weight:  4341
# Actual:  14.0      Predicted:  12.9      Weight:  4354
# Actual:  14.0      Predicted:  13.2      Weight:  4312
# Actual:  14.0      Predicted:  12.3      Weight:  4425
# Actual:  15.0      Predicted:  16.8      Weight:  3850
# Actual:  15.0      Predicted:  19.0      Weight:  3563
# Actual:  14.0      Predicted:  18.6      Weight:  3609
# Actual:  15.0      Predicted:  17.4      Weight:  3761
# Actual:  14.0      Predicted:  22.6      Weight:  3086
# Actual:  24.0      Predicted:  28.1      Weight:  2372
# Actual:  22.0      Predicted:  24.6      Weight:  2833
# Actual:  18.0      Predicted:  25.0      Weight:  2774
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
data = pd.read_csv('auto-mpg.csv')

data['horsepower'].replace('?', 99.9, inplace=True)
X = data[['weight', 'horsepower', 'cylinders', 'acceleration', 'displacement', 'model year', 'origin']].values
y = data['mpg']

#plt.scatter(X, y)

model = LinearRegression(fit_intercept=False)
clf = model.fit(X, y)
print('Coefficient: ', clf.coef_)


predictions = model.predict(X)
for index in range(len(predictions)):
    print ('Actual: ', y[index], '    ', 'Predicted: ', format(predictions[index], ".1f"),'    ')
#plt.plot(X, predictions)
# Out:
# Coefficient:  [-0.00627039 -0.03436113 -0.65138592 -0.06249679  0.02091825  0.58165948
#   1.2839574 ]
# Actual:  18.0      Predicted:  16.0
# Actual:  15.0      Predicted:  14.6
# Actual:  18.0      Predicted:  16.1
# Actual:  16.0      Predicted:  15.7
# Actual:  17.0      Predicted:  16.0
# Actual:  15.0      Predicted:  11.1
# Actual:  14.0      Predicted:  10.9
# Actual:  14.0      Predicted:  11.0
# Actual:  14.0      Predicted:  10.2
# Actual:  15.0      Predicted:  13.7
# Actual:  15.0      Predicted:  16.0
# Actual:  14.0      Predicted:  15.3
# Actual:  15.0      Predicted:  15.8
# Actual:  14.0      Predicted:  18.6
# Actual:  24.0      Predicted:  25.3
# Actual:  22.0      Predicted:  20.2
# Actual:  18.0      Predicted:  20.6
# Actual:  21.0      Predicted:  22.1
# Actual:  27.0      Predicted:  26.7
# Actual:  26.0      Predicted:  28.3
# Actual:  25.0      Predicted:  22.1
# Actual:  24.0      Predicted:  23.7
# Actual:  25.0      Predicted:  23.6
# ...
